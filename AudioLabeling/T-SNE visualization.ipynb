# %%
import numpy as np
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from time import time
import matplotlib.pyplot as plt
import os
import pickle
import scipy
from sklearn.preprocessing import StandardScaler
from scipy.special import comb

from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# %%
features_folder = "C:\\Users\\t-anmend\\Documents\\train_1\\"

# %%
with open(os.path.join(features_folder,'train1_stats_features.txt'),'rb') as f:
    features  = pickle.load(f)

# %%
features = np.array(features)

# %%
features_stats = np.zeros((features.shape[0],len(features[0][0])))
for i in range(features.shape[0]):
    features_stats[i] = features[i][0]

# %%
features_stats.shape
# Out:
# (3000, 896)

# %%
labels = []
for i in range(features.shape[0]):
    labels.append(features[i][1])

# %%
n_samples, n_features = features_stats.shape
labels_ = []

for i in range(len(labels)):
    for j in range(len(labels[i])):
        labels_.append(labels[i][j])
    
n_labels = len(np.unique(labels_))

sample_size = 300

# %%
print("n_labels: %d, \t n_samples %d, \t n_features %d"
      % (n_labels, n_samples, n_features))
# Out:
# n_labels: 10, 	 n_samples 3000, 	 n_features 896

# %% [markdown]
# # T-SNE visualization

# %%
X_embedded = TSNE(n_components=2, verbose=1, perplexity=40).fit_transform(features_stats)
X_embedded.shape
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3000 samples in 0.160s...
# [t-SNE] Computed neighbors for 3000 samples in 16.201s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3000
# [t-SNE] Computed conditional probabilities for sample 2000 / 3000
# [t-SNE] Computed conditional probabilities for sample 3000 / 3000
# [t-SNE] Mean sigma: 180.205823
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.042137
# [t-SNE] KL divergence after 1000 iterations: 2.468717
# (3000, 2)

# %%
data = pd.DataFrame(X_embedded)

# %%
data.columns = ['X','Y']

# %%
data['labels'] = labels

# %%
data
# Out:
#               X          Y                                             labels
# 0    -27.412380 -10.541118  [drilling, dog_bark, air_conditioner, children...
# 1    -17.030283 -12.710319  [dog_bark, drilling, siren, street_music, gun_...
# 2    -30.631807 -10.564416  [drilling, children_playing, dog_bark, street_...
# 3    -10.514343 -19.095741  [air_conditioner, air_conditioner, siren, jack...
# 4     -7.439798 -29.943626  [jackhammer, jackhammer, air_conditioner, chil...
# 5     14.183912 -31.338585  [air_conditioner, air_conditioner, drilling, j...
# 6    -20.544552 -33.958408  [children_playing, air_conditioner, siren, eng...
# 7      8.830735  16.277035  [car_horn, dog_bark, gun_shot, siren, children...
# 8    -18.596432   3.078678  [car_horn, engine_idling, drilling, dog_bark, ...
# 9     -5.203869  -0.392674  [gun_shot, drilling, dog_bark, car_horn, child...
# 10   -13.635653 -17.367817  [dog_bark, dog_bark, jackhammer, engine_idling...
# 11     0.698761  -9.225752  [gun_shot, siren, engine_idling, gun_shot, str...
# 12   -13.903417 -40.063114  [air_conditioner, engine_idling, street_music,...
# 13     2.127777 -15.595749  [drilling, dog_bark, jackhammer, car_horn, sir...
# 14   -11.044943  -0.846081  [air_conditioner, air_conditioner, car_horn, c...
# 15   -10.079906  34.538490  [drilling, siren, street_music, siren, street_...
# 16   -12.396294   5.693093  [children_playing, children_playing, siren, si...
# 17   -37.332432 -21.176600                     [dog_bark, gun_shot, car_horn]
# 18    -0.413048  -5.045850  [street_music, drilling, engine_idling, siren,...
# 19   -14.557491  41.686527  [jackhammer, street_music, dog_bark, siren, dr...
# 20   -24.710443 -10.663520  [air_conditioner, engine_idling, children_play...
# 21    22.495058 -20.763765  [drilling, air_conditioner, drilling, engine_i...
# 22   -38.848698   3.271687  [children_playing, air_conditioner, children_p...
# 23   -19.796743   4.244732  [car_horn, car_horn, dog_bark, children_playin...
# 24    21.870981 -22.142862          [air_conditioner, jackhammer, jackhammer]
# 25   -35.604275  -1.709506                     [gun_shot, car_horn, car_horn]
# 26   -12.508573  17.041462  [street_music, children_playing, drilling, dog...
# 27    -0.032548  -7.162556  [air_conditioner, air_conditioner, gun_shot, s...
# 28   -27.300278  14.192348  [dog_bark, dog_bark, dog_bark, drilling, car_h...
# 29    -2.095387   4.526621  [engine_idling, children_playing, street_music...
# ...         ...        ...                                                ...
# 2970  10.549326 -37.302071         [dog_bark, drilling, car_horn, jackhammer]
# 2971  24.588110  17.586683  [siren, street_music, children_playing, air_co...
# 2972  38.762844  -3.155398                        [siren, dog_bark, drilling]
# 2973  22.014059  13.175388  [siren, jackhammer, gun_shot, dog_bark, car_ho...
# 2974  23.241291 -29.245829            [gun_shot, siren, jackhammer, car_horn]
# 2975  18.185720  11.679781  [dog_bark, engine_idling, siren, children_play...
# 2976  -0.293248 -11.092077  [air_conditioner, engine_idling, siren, gun_sh...
# 2977 -34.336800 -12.150355  [engine_idling, street_music, street_music, do...
# 2978  36.790329   6.590283  [jackhammer, car_horn, drilling, gun_shot, chi...
# 2979 -22.732409 -15.004536  [children_playing, air_conditioner, gun_shot, ...
# 2980  10.718196 -12.861310  [engine_idling, street_music, air_conditioner,...
# 2981  25.789246  -5.882838                           [siren, car_horn, siren]
# 2982   6.066278 -22.411190  [dog_bark, drilling, drilling, street_music, s...
# 2983 -35.441517  21.619061  [dog_bark, drilling, car_horn, street_music, j...
# 2984  -4.934304  12.385043  [siren, engine_idling, jackhammer, car_horn, j...
# 2985  19.642733  15.400413  [gun_shot, dog_bark, siren, street_music, dog_...
# 2986 -22.907743  31.068266  [siren, air_conditioner, air_conditioner, dril...
# 2987   5.201624  37.911098  [engine_idling, children_playing, air_conditio...
# 2988  13.035110 -13.814639  [air_conditioner, car_horn, street_music, dril...
# 2989  24.133440   2.156950  [jackhammer, jackhammer, air_conditioner, dog_...
# 2990 -15.312284  -3.606014  [dog_bark, drilling, children_playing, dog_bar...
# 2991  -0.457404  37.280930  [children_playing, gun_shot, jackhammer, drill...
# 2992  29.926039 -26.903681  [gun_shot, gun_shot, children_playing, street_...
# 2993 -28.635750  11.132643  [drilling, car_horn, street_music, children_pl...
# 2994  -5.234892 -36.550976  [dog_bark, car_horn, siren, air_conditioner, s...
# 2995 -14.126030  -7.629313  [dog_bark, engine_idling, engine_idling, child...
# 2996 -36.903767  18.800943            [car_horn, engine_idling, street_music]
# 2997   1.085821 -44.004021  [drilling, dog_bark, jackhammer, engine_idling...
# 2998   6.143190 -33.647518  [children_playing, drilling, engine_idling, en...
# 2999 -11.019176 -38.830433  [air_conditioner, air_conditioner, engine_idli...
#
# [3000 rows x 3 columns]

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x='X', y='Y',
    hue="labels",
    palette=sns.color_palette("hls", 10),
    data=data,
    legend="full",
    alpha=0.3
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, data)
#    2490     def __init__(self, data):
# -> 2491         self._validate(data)
#    2492         self._parent = data.values
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\arrays\categorical.py in _validate(data)
#    2499         if not is_categorical_dtype(data.dtype):
# -> 2500             raise AttributeError("Can only use .cat accessor with a "
#    2501                                  "'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-45646a824a3f> in <module>
#       6     data=data,
#       7     legend="full",
# ----> 8     alpha=0.3
#       9 )
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     857         )
#     858
# --> 859         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     860         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     861         self.parse_style(plot_data["style"], markers, None, style_order)
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\relational.py in parse_hue(self, data, palette, order, norm)
#     365             limits = None
#     366             levels, palette = self.categorical_to_palette(
# --> 367                 data, order, palette
#     368             )
#     369
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\relational.py in categorical_to_palette(self, data, order, palette)
#     195
#     196         if order is None:
# --> 197             levels = categorical_order(data)
#     198         else:
#     199             levels = order
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     527             except (TypeError, AttributeError):
#     528                 try:
# --> 529                     order = values.unique()
#     530                 except AttributeError:
#     531                     order = pd.unique(values)
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\series.py in unique(self)
#    1665         Categories (3, object): [a < b < c]
#    1666         """
# -> 1667         result = super(Series, self).unique()
#    1668         return result
#    1669
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\base.py in unique(self)
#    1312         else:
#    1313             from pandas.core.algorithms import unique1d
# -> 1314             result = unique1d(values)
#    1315
#    1316         return result
#
# ~\AppData\Local\Continuum\anaconda3\envs\clustering\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     360
#     361     table = htable(len(values))
# --> 362     uniques = table.unique(values)
#     363     uniques = _reconstruct_data(uniques, dtype, original)
#     364     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
